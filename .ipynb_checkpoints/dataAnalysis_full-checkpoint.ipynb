# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import pandas as pd
import time
import json
import pandas as pd
import matplotlib.pyplot as plt


import pandas as pd
import folium
import json
import requests

minimal_player_count_to_filter = 10

minimal_rating_to_consider = 2900 # When we get to player ranked less than that. we stop

# %%
def scrape_chess_leaderboard_full(page=1):
    url = f"https://www.chess.com/leaderboard/live?page={page}"
    options = Options()
    options.add_argument("--headless")
    driver = webdriver.Chrome(options=options)

    driver.get(url)
    time.sleep(5)  # Wait for JS to load

    rows = driver.find_elements(By.CSS_SELECTOR, "tr.leaderboard-row-show-on-hover")
    data = []

    for row in rows:
        try:
            # Player name
            name_elem = row.find_element(By.CLASS_NAME, "cc-user-username-component")
            name = name_elem.text.strip()
            country = "unknown"
            try:
                # Country code (your method)
                country_div = row.find_element(By.CSS_SELECTOR, "div[class*='country-']")
                country_classes = country_div.get_attribute("class").split()
                country = [c for c in country_classes if c.startswith("country-") and "flags" not in c][0]
                country_code = country.split("-")[1]
            except:
                print(f"failed to get country: name: {name}")
            rating = "-1"
            try:   
                # Rating
                rating_elem = row.find_elements(By.CSS_SELECTOR, "td.leaderboard-table-text-right")[1]
                rating = rating_elem.text.strip()
            except: 
                print(f"Failed to get ranking. Name: {name}")
                
            data.append({
                "Player Name": name,
                "Country Code": country_code,
                "Rating": rating
            })

        except Exception as e:
            print(f"failure: {e}")  # Skip any row that causes an error

    driver.quit()

    return pd.DataFrame(data)

# %%
# Example usage
all_data = []
page = 1
while(True):
    print(f"Scraping page {page}")
    df = scrape_chess_leaderboard_full(page)
    all_data.append(df)
    min_value = df["Rating"].min()
    print(f"min: {min_value}")
    page +=1
    if (int(min_value) < minimal_rating_to_consider):
        break

final_df = pd.concat(all_data, ignore_index=True)
# Out:
# Scraping page 1
# player: Hikaru, country: 78, rating: 3300
# player: MagnusCarlsen, country: 104, rating: 3252
# player: LyonBeast, country: 52, rating: 3235
# player: FabianoCaruana, country: 2, rating: 3205
# player: Firouzja2003, country: 52, rating: 3204
# player: GMWSO, country: 2, rating: 3196
# player: HansOnTwitch, country: 2, rating: 3191
# failed to get country: name: DenLaz
# player: DenLaz, country: 2, rating: 3184
# player: Philippians46, country: 2, rating: 3171
# player: Konavets, country: 2, rating: 3168
# failed to get country: name: lachesisQ
# player: lachesisQ, country: 2, rating: 3166
# player: rpragchess, country: 69, rating: 3161
# player: mishanick, country: 231, rating: 3158
# player: Njal28, country: 14, rating: 3154
# player: legendisback1, country: 138, rating: 3150
# player: Javokhir_Sindarov05, country: 145, rating: 3145
# player: Polish_fighter3000, country: 112, rating: 3140
# player: FairChess_on_YouTube, country: 314, rating: 3139
# player: Bigfish1995, country: 127, rating: 3136
# player: Dr_Tyger, country: 33, rating: 3134
# player: VincentKeymer, country: 54, rating: 3133
# player: LiemLe, country: 149, rating: 3129
# player: ChessWarrior7197, country: 145, rating: 3127
# player: NikoTheodorou, country: 56, rating: 3126
# player: Sargsyan_Shant, country: 14, rating: 3125
# player: Msb2, country: 54, rating: 3125
# player: Zkid, country: 2, rating: 2934
# player: elm2007, country: 350, rating: 2934
# player: MolecularChemist, country: 56, rating: 2933
# player: yosephtaher, country: 70, rating: 2933
# player: TrainningAc, country: 33, rating: 2933
# player: hansen, country: 3, rating: 2933
# player: lilleper1, country: 41, rating: 2932
# player: ulises2013, country: 163, rating: 2932
# player: HVillagra, country: 32, rating: 2931
# player: yavrukurt40, country: 138, rating: 2930
# player: Kirill_Klukin, country: 231, rating: 2930
# player: Nitzan_Steinberg, country: 75, rating: 2930
# player: DontOfferMeADraw, country: 112, rating: 2929
# player: kingofthenil, country: 52, rating: 2929
# player: TenisMaster, country: 2, rating: 2929
# player: PeacefulWarrior888, country: 2, rating: 2929
# player: abhidabhi, country: 69, rating: 2929
# player: MarkusRagger, country: 18, rating: 2929
# player: Yaacovn, country: 2, rating: 2928
# player: Arystanner, country: 81, rating: 2928
# player: pouya21, country: 71, rating: 2928
# failed to get country: name: SavelijTartakover
# player: SavelijTartakover, country: 71, rating: 2928
# player: Leon009, country: 95, rating: 2926
# player: superchess02, country: 69, rating: 2925
# player: SaraciNderim, country: 317, rating: 2925
# player: Yan_Dyomin2010, country: 141, rating: 2925
# failed to get country: name: JeRoma71
# player: JeRoma71, country: 141, rating: 2925
# player: vlad10898, country: 141, rating: 2925
# player: justantan, country: 17, rating: 2925
# player: mitrabhaa, country: 69, rating: 2924
# player: michaelq2d5, country: 2, rating: 2923
# player: AbasovN, country: 156, rating: 2920
# player: TanitoluwaAps116, country: 82, rating: 2920
# player: Genghis_K, country: 4, rating: 2920
# player: Sardaukar-2, country: 141, rating: 2917
# min: 2917
# Scraping page 7
# player: 2bf41-0, country: 2, rating: 2917
# player: Little_Skib, country: 2, rating: 2916
# player: chess_master_8820, country: 71, rating: 2916
# player: IMchanged, country: 115, rating: 2916
# player: Igor_Kowalski, country: 112, rating: 2915
# player: EddieMarsalla, country: 36, rating: 2915
# player: crescentmoon2411, country: 149, rating: 2914
# player: vas04hou, country: 225, rating: 2914
# player: Bartek_Turski, country: 112, rating: 2913
# failed to get country: name: TrahtarBelarus
# player: TrahtarBelarus, country: 112, rating: 2913
# player: Negocia, country: 112, rating: 2913
# player: the_chess_child, country: 69, rating: 2913
# player: Semyon_Khanin, country: 2, rating: 2912
# player: tsaruk_maks, country: 225, rating: 2911
# failed to get country: name: GoltsevDmitry2000
# player: GoltsevDmitry2000, country: 225, rating: 2911
# player: PlayForFun06, country: 66, rating: 2911
# player: temus_galaktionov, country: 142, rating: 2911
# failed to get country: name: quvnoq_muxlis
# player: quvnoq_muxlis, country: 142, rating: 2911
# player: ckgchess, country: 138, rating: 2911
# player: GilbertElroy, country: 70, rating: 2911
# player: eljanov, country: 141, rating: 2910
# player: Tapuah, country: 75, rating: 2909
# player: klimkoj, country: 112, rating: 2909
# failed to get country: name: Kezin_Roman
# player: Keranke, country: 71, rating: 2894
# player: GMAkobianSTL, country: 2, rating: 2894
# player: Zhalmakhanov_Ramazan, country: 81, rating: 2893
# player: vanea_03, country: 96, rating: 2893
# player: Reader777, country: 132, rating: 2893
# player: Ga_R, country: 76, rating: 2893
# player: ToivoK3, country: 51, rating: 2892
# player: VitaliyBernadskiy, country: 141, rating: 2892
# player: RobertoJBM, country: 27, rating: 2891
# player: youngKID, country: 69, rating: 2889
# player: David_Arutinian, country: 53, rating: 2889
# player: isPalindrome, country: 315, rating: 2888
# player: bestofbestkiller, country: 33, rating: 2887
# player: bubeliang, country: 104, rating: 2887
# player: unkiyto, country: 33, rating: 2887
# min: 2887

# %% [markdown]
# ## Group by country

# %%
players_by_country = final_df.groupby("Country Code").size().reset_index(name="Player Count")

# %%
import json

with open("country_mapping.json", "r", encoding="utf-8") as f:
    country_codes = json.load(f)
with open("countries_population.json", "r", encoding="utf-8") as f:
    country_population = json.load(f)

# %%
name_to_population = dict()
for i in country_population:
    name_to_population[i["Country Name"]] = i["Population"]

# %%
code_to_name = {entry["id"]: entry["name"] for entry in country_codes}

# %%
# Define a function
def country_name(row):
    t = row["Country Code"]
    return code_to_name[int(t)]

final_df["country_name"] = final_df.apply(country_name, axis=1)

# %%
final_df
# Out:
#           Player Name Country Code Rating   country_name
# 0              Hikaru           78   3300          Japan
# 1       MagnusCarlsen          104   3252         Norway
# 2           LyonBeast           52   3235         France
# 3      FabianoCaruana            2   3205  United States
# 4        Firouzja2003           52   3204         France
# ..                ...          ...    ...            ...
# 395   David_Arutinian           53   2889        Georgia
# 396      isPalindrome          315   2888      Catalonia
# 397  bestofbestkiller           33   2887          China
# 398         bubeliang          104   2887         Norway
# 399           unkiyto           33   2887          China
#
# [400 rows x 4 columns]

# %%
def country_population(row):
    t = row["country_name"]
    if (t in name_to_population):
        return name_to_population[t]
    print(f"missing population: {t}")
    return 1
    

final_df["country_population"] = final_df.apply(country_population, axis=1)
# Out:
# missing population: International
# missing population: International
# missing population: International
# missing population: Olympic
# missing population: International
# missing population: International
# missing population: England
# missing population: International
# missing population: International
# missing population: International
# missing population: Olympic
# missing population: International
# missing population: International
# missing population: Turks & Caicos Islands
# missing population: Bosnia & Herzegovina
# missing population: International
# missing population: International
# missing population: International
# missing population: Hong Kong SAR China
# missing population: Catalonia

# %%
final_df
# Out:
#           Player Name Country Code Rating   country_name  country_population
# 0              Hikaru           78   3300          Japan           124517000
# 1       MagnusCarlsen          104   3252         Norway             5520000
# 2           LyonBeast           52   3235         France            68287000
# 3      FabianoCaruana            2   3205  United States           334915000
# 4        Firouzja2003           52   3204         France            68287000
# ..                ...          ...    ...            ...                 ...
# 395   David_Arutinian           53   2889        Georgia             3715000
# 396      isPalindrome          315   2888      Catalonia                   1
# 397  bestofbestkiller           33   2887          China          1410710000
# 398         bubeliang          104   2887         Norway             5520000
# 399           unkiyto           33   2887          China          1410710000
#
# [400 rows x 5 columns]

# %%
players_by_country = final_df.groupby("country_name").size().reset_index(name="Player Count")

# %%
players_by_country
# Out:
#             country_name  Player Count
# 0                Andorra             1
# 1              Argentina             4
# 2                Armenia             9
# 3              Australia             2
# 4                Austria             2
# ..                   ...           ...
# 69  United Arab Emirates             6
# 70         United States            48
# 71               Uruguay             1
# 72            Uzbekistan            10
# 73               Vietnam             6
#
# [74 rows x 2 columns]

# %%
players_by_country["country_population"] = players_by_country.apply(country_population, axis=1)
# Out:
# missing population: Bosnia & Herzegovina
# missing population: Catalonia
# missing population: England
# missing population: Hong Kong SAR China
# missing population: International
# missing population: Olympic
# missing population: Turks & Caicos Islands

# %%
players_by_country
# Out:
#             country_name  Player Count  country_population
# 0                Andorra             1               81000
# 1              Argentina             4            45538000
# 2                Armenia             9             2991000
# 3              Australia             2            26659000
# 4                Austria             2             9132000
# ..                   ...           ...                 ...
# 69  United Arab Emirates             6            10484000
# 70         United States            48           334915000
# 71               Uruguay             1             3388000
# 72            Uzbekistan            10            35652000
# 73               Vietnam             6           100352000
#
# [74 rows x 3 columns]

# %%
players_by_country["players per million"] = (players_by_country["Player Count"] / players_by_country["country_population"]) * 1_000_000

# %%
players_by_country
# Out:
#             country_name  Player Count  country_population  \
# 0                Andorra             1               81000
# 1              Argentina             4            45538000
# 2                Armenia             9             2991000
# 3              Australia             2            26659000
# 4                Austria             2             9132000
# ..                   ...           ...                 ...
# 69  United Arab Emirates             6            10484000
# 70         United States            48           334915000
# 71               Uruguay             1             3388000
# 72            Uzbekistan            10            35652000
# 73               Vietnam             6           100352000
#
#     players per million
# 0             12.345679
# 1              0.087839
# 2              3.009027
# 3              0.075022
# 4              0.219010
# ..                  ...
# 69             0.572301
# 70             0.143320
# 71             0.295159
# 72             0.280489
# 73             0.059790
#
# [74 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt


import pandas as pd
import folium
import json
import requests

# Filter for countries with more than 100 players
players_by_country = players_by_country[players_by_country["Player Count"] > minimal_player_count_to_filter].copy()
players_by_country = players_by_country[players_by_country["country_population"] > 1000].copy()

# %%
players_by_country
# Out:
#      country_name  Player Count  country_population  players per million
# 5      Azerbaijan            17            10154000             1.674217
# 13          China            13          1410710000             0.009215
# 22         France            17            68287000             0.248949
# 31          India            38          1438070000             0.026424
# 34           Iran            16            90609000             0.176583
# 54         Poland            23            36687000             0.626925
# 61          Spain            12            48348000             0.248201
# 68        Ukraine            15            37733000             0.397530
# 70  United States            48           334915000             0.143320

# %%
# Sort by value (optional)
df_sorted = players_by_country.sort_values("players per million", ascending=False)[:20]

# Plot bar chart
plt.figure(figsize=(10, 6))
plt.barh(df_sorted["country_name"], df_sorted["players per million"], color='skyblue')
plt.xlabel("Players Per Million")
plt.title(f">{minimal_rating_to_consider} Chess.com Players Per Million by Country")
plt.gca().invert_yaxis()  # Highest value at the top
plt.tight_layout()
plt.show()
